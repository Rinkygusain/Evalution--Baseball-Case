# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
data.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
import seaborn as sns
sns.heatmap(data.isnull(),yticklabels=False, cbar=False, cmap='viridis') #no null value present
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.isna(),yticklabels=False, cbar=False, cmap='viridis') #no null value present
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (30, 17)

# %%
#EDA
data['W'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['R'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['AB'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['H'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['2B'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['2B'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['3B'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['HR'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['BB'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['SO'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['SB'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['RA'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['ER'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['ERA'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['CG'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['SHO'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['SV'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
data['E'].hist(bins=40,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="R",y='W',data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot(x="AB",y='W',data=data)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot(x="H",y='W',data=data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot(x="2B",y='W',data=data)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot(x="3B",y='W',data=data)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.pairplot(data)

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(data.describe(), annot=True, linewidth=.5,linecolor='red')
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot=True, linewidth=.5,linecolor='red')
# Out:
# <AxesSubplot:>

# %%
data.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize=(12,10))
data.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='green')
plt.xlabel('details',fontsize=16)
plt.ylabel('column with target names',fontsize=16)
plt.title('correlation',fontsize=20)
plt.show()

# %%
#to check the outliers
import warnings
warnings.filterwarnings('ignore')
collist=data.columns.values
ncol=3
nrows=6
plt.figure(figsize=(nrows,4*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data[collist[i]])
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(data))
threshold=3
np.where(z>3)
# Out:
# (array([5]), array([1]))

# %%
np.abs(zscore(data))<0
# Out:
# array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False],
# ...

# %%
data_1=data[(z<3).all(axis=1)]
data_1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
data_1.shape
# Out:
# (29, 17)

# %%
data.shape
# Out:
# (30, 17)

# %%
#check loss data percentage
loss_data=((30-29)/30)*100
loss_data
# Out:
# 3.3333333333333335

# %%
#check skewness in data
data.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# RA     0.045734
# W      0.047089
# ERA    0.053331
# ER     0.058710
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SB     0.479893
# HR     0.516441
# SHO    0.565790
# SV     0.657524
# H      0.670254
# CG     0.736845
# E      0.890132
# R      1.200786
# dtype: float64

# %%
#distribution plot to check skewness
collist=data.columns.values
ncol=2
nrows=9
plt.figure(figsize=(nrows,7*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(data[collist[i]])
    plt.tight_layout()

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f5b0f9a021ad> in <module>
#       1 from sklearn.preprocessing import power_transform
# ----> 2 x=power_transform(x,method='yeo-johnson')
#       3 x
#
# NameError: name 'x' is not defined

# %%
x.skew()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  1.48589294,  1.03641979,
#         -0.76109695, -1.60261052, -2.53925814,  0.9395667 , -0.66148725,
#         -0.50166065, -0.50522506, -0.37510382, -0.7904002 ,  1.53977742,
#         -0.31839526],
#        [ 0.        ,  0.        ,  0.        ,  0.07744806,  1.21373307,
#         -0.14782963, -0.50667713,  0.12861529, -0.54355056,  0.17319489,
#          0.25239742,  0.25607157, -0.37510382,  0.24897999,  0.36451372,
#         -0.51969733],
#        [ 0.        ,  0.        ,  0.        ,  1.6825646 , -0.17920749,
#         -0.68483534,  1.13019313, -0.90160363,  0.20636898, -0.67572815,
#         -0.74905309, -0.63969175,  2.04102723, -0.24819391, -0.60490527,
#         -1.36001814],
#        [ 0.        ,  0.        ,  0.        , -0.85004498, -0.37708653,
#         -0.87771937, -1.17873561, -0.19573807, -0.64562658,  0.18725743,
#          0.10757606,  0.05453636,  1.23008931, -0.51281005, -0.76290915,
#          0.68786181],
# ...

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score
lr=LinearRegression()

# %%
x=data.drop('W',axis=1)
y=data['W']

# %%
for i in range(0,20):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(y_train,pred_train)*100}")
    print(f"At random state {i},the training accuracy is:- {r2_score(y_test,pred_test)*100}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 96.0959061883554
# At random state 0,the training accuracy is:- 66.29341689506629
#
#
# At random state 1,the training accuracy is:- 97.15846357165398
# At random state 1,the training accuracy is:- 38.41724690075951
#
#
# At random state 2,the training accuracy is:- 98.98192153844538
# At random state 2,the training accuracy is:- -208.19989550103887
#
#
# At random state 3,the training accuracy is:- 97.22553885185529
# At random state 3,the training accuracy is:- 46.18378970602336
#
#
# At random state 4,the training accuracy is:- 96.47461497996576
# At random state 4,the training accuracy is:- 46.606852927283406
#
#
# At random state 5,the training accuracy is:- 95.03092887369992
# At random state 5,the training accuracy is:- 75.17105066858531
#
#
# At random state 6,the training accuracy is:- 94.89470045214469
# At random state 6,the training accuracy is:- 83.7641952186839
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=19,test_size=0.20)
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test)*100)
# Out:
# 83.81134193356614

# %%
from sklearn.model_selection import cross_val_score 
from sklearn.datasets import load_boston
boston=load_boston()
x_train,x_test,y_train,y_test=train_test_split(boston.data,boston.target,train_size=.75)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
mean_absolute_error(y_test,y_pred)
# Out:
# 3.509317226266448

# %%
x=boston.data
y=boston.target
multireg=LinearRegression()
lr_score=cross_val_score(multireg,x,y,cv=10,scoring='neg_mean_absolute_error')
lr_score_n=-lr_score
lr_score_n
# Out:
# array([2.20686845, 2.89680909, 2.78673044, 4.59847835, 4.10986504,
#        3.56469238, 2.66966723, 9.65637767, 5.02272517, 2.53725254])

# %%
np.mean(lr_score_n)
# Out:
# 4.004946635324006

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators=[int(x) for x in np.linspace(10,100,15)]
max_features=['auto','sqrt','log2']
max_depth=[int(x) for x in np.linspace(10,100,15)]
min_samples_split=[2,5,10,23,21]
min_samples_leaf=[1,2,12,24,21]
random_grid={'n_estimators':n_estimators,
            'max_features':max_features,
            'max_depth':max_depth,
            'min_samples_split':min_samples_split,
            'min_samples_leaf':min_samples_leaf,
            'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'n_estimators': [10, 16, 22, 29, 35, 42, 48, 55, 61, 67, 74, 80, 87, 93, 100], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 16, 22, 29, 35, 42, 48, 55, 61, 67, 74, 80, 87, 93, 100], 'min_samples_split': [2, 5, 10, 23, 21], 'min_samples_leaf': [1, 2, 12, 24, 21], 'criterion': ['entropy', 'gini']}

# %%
rf_cv.best_params_
# Out:
# {'n_estimators': 10,
#  'min_samples_split': 21,
#  'min_samples_leaf': 12,
#  'max_features': 'sqrt',
#  'max_depth': 39,
#  'criterion': 'entropy'}

# %%
rf_cv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=39, max_features='sqrt',
#                        min_samples_leaf=12, min_samples_split=21,
#                        n_estimators=10)

# %%
pred=lr.predict(x_test)
print("Predicted W:",pred)
print("actual W",y_test)
# Out:
# Predicted W: [22.84323883 14.57702823 23.93398377 23.05873709 16.43324425 15.37389644
#  25.76774503 18.87859018 22.36918007 23.65062254 23.6996757  12.76934977
#  34.79887881 11.34678204 32.22521964 27.52871716 31.13125298 27.4346094
#  27.14449751 21.30259623 20.33279945 34.36326761 18.8759503  24.09091882
#  35.8889791  24.6394059  40.03470993 21.04331943 19.48376749 32.43276441
#   6.50729497 32.2943972   5.49636492 20.88136894 22.38927132 26.48327979
#  28.59710676 24.50842295 17.7478061   3.96547746 20.37070386 20.41023776
#  30.58551044 17.05775609 22.19178038 31.90337438 12.7450812  24.64612815
#  25.35180657 19.0793643  10.77050828 14.61480764  6.43526624 34.79667985
#  25.34690689 21.1027421  18.7574912  31.7083283   3.30981835 27.51723727
#  24.86089913 21.46754422 21.49996845 25.36431112 16.54876791 21.73310886
#  13.08197138 15.70884794 18.62268261 10.24046473 35.17888461 37.64403372
#  21.21017658 11.02129267 29.65946395 15.99820381 12.87779489 18.13021374
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='g')
plt.plot(y_test,y_test,color='b')
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
#Model Saving
import pickle
filename='Baseball study'
pickle.dump(lr,open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
data_2=pd.DataFrame({"Original":a,"predicted":predicted},index=range(len(a)))
data_2
# Out:
#      Original  predicted
# 0        22.9  22.843239
# 1        15.4  14.577028
# 2        21.7  23.933984
# 3        20.8  23.058737
# 4        17.6  16.433244
# ..        ...        ...
# 122      29.6  24.798593
# 123      35.4  30.592621
# 124      18.5  13.244884
# 125      17.8  20.763270
# 126      30.1  34.770994
#
# [127 rows x 2 columns]
